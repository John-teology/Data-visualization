# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('Titanic.csv')
dffinal = df.dropna()
df.head(10)
# Out:
#        last                                    first gender   age  class  \
# 0    Abbing                              Mr. Anthony      M  42.0      3
# 1    Abbott                 Mrs. Stanton (Rosa Hunt)      F  35.0      3
# 2    Abbott                      Mr. Rossmore Edward      M  16.0      3
# 3   Abelson                               Mr. Samuel      M  30.0      2
# 4   Abelson             Mrs. Samuel (Hannah Wizosky)      F  28.0      2
# 5     Adahl                  Mr. Mauritz Nils Martin      M  30.0      3
# 6     Adams                                 Mr. John      M  26.0      3
# 7     Ahlin  Mrs. Johan (Johanna Persdotter Larsson)      F  40.0      3
# 8       Aks                    Mrs. Sam (Leah Rosen)      F  18.0      3
# 9  Albimona                        Mr. Nassef Cassem      M  26.0      3
#
#     fare     embarked survived
# 0   7.55  Southampton       no
# 1  20.25  Southampton      yes
# 2  20.25  Southampton       no
# 3  24.00    Cherbourg       no
# ...

# %%
df.shape
# Out:
# (891, 8)

# %%
df.isna().any()
# Out:
# last        False
# first       False
# gender      False
# age          True
# class       False
# fare        False
# embarked    False
# survived    False
# dtype: bool

# %%
df2 = pd.read_csv('synoptic.csv')
df2.head()
# Out:
#          DateTime  Amount of Rainfall  Code
# 0   8/1/2020 2:00                   1   435
# 1   8/1/2020 5:00                   9   435
# 2   8/1/2020 8:00                   7   435
# 3  8/1/2020 11:00                   1   435
# 4  8/1/2020 14:00                   5   435

# %%
df3 = pd.read_csv('tips.csv')
df3.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df4=pd.read_csv('penguins_size.csv')
df4final =df4.dropna()
df4final.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 4  Adelie  Torgersen              36.7             19.3              193.0
# 5  Adelie  Torgersen              39.3             20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 4       3450.0  FEMALE
# 5       3650.0    MALE

# %% [markdown]
# ## PAIRPLOT

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   last      891 non-null    object
#  1   first     891 non-null    object
#  2   gender    891 non-null    object
#  3   age       714 non-null    float64
#  4   class     891 non-null    int64
#  5   fare      891 non-null    float64
#  6   embarked  891 non-null    object
#  7   survived  891 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 55.8+ KB

# %%
sns.pairplot(df, hue = 'gender')        
plt.show()

# %%
sns.kdeplot(data = df,x ='age', hue = 'gender')
plt.show()

# %%
sns.relplot(x = 'fare', y= 'age' ,hue = 'gender',data = df , kind ='scatter')
plt.xlim(0,100)
plt.title("Fare per Age and Gender")
plt.xlabel('fare')
plt.ylabel('age')
plt.show()

# %% [markdown]
# ## POINTPLOT

# %%
sns.pointplot(y="age", 
 x ="gender",  
 hue = 'survived',
 data=df, 
 linestyles=["-","--"],dodge = True)  #dodge


plt.show()

# %%
sns.barplot(y="age", 
 x ="gender",  
 hue = 'survived',
 data=df)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='age'>

# %%
sns.pointplot(y = "sex",
              x = "total_bill",
              data = df3, order = ['Male','Female']) 
plt.show()

# %% [markdown]
# ## VIOLINPLOT

# %%
sns.set_theme(style="darkgrid")
ax = sns.violinplot(y="age",
 x="gender",
 hue="survived",
 data = df, inner = 'sticks'
 )
plt.legend(bbox_to_anchor=(1.2, 1))
plt.show()

# %% [markdown]
# ## BOXPLOT

# %%
fig , ax = plt.subplots(figsize = [10,5])
ax = sns.boxplot(data = df , x = 'age', y='gender',hue = 'survived')
ax = sns.stripplot(data = df , x = 'age', y='gender',hue = 'survived',dodge = True,color = '0.5')
plt.legend(bbox_to_anchor=(1.1, 1))
plt.show()

# %%
ax = sns.boxplot(data = df3, x ='day',y='total_bill',hue ='sex')
plt.legend(bbox_to_anchor=(1.3, 1))

plt.show()

# %% [markdown]
# ## PIE CHART

# %%
df.embarked.value_counts().plot(kind ='pie',figsize =(5,5))  
plt.show()

# %%
df[df.embarked == 'Southampton'].count()
# Out:
# last        646
# first       646
# gender      646
# age         556
# class       646
# fare        646
# embarked    646
# survived    646
# dtype: int64

# %%
sns.set_theme(style="darkgrid")
df.gender.value_counts().plot(kind ='pie',figsize =(5,5))
plt.title('Gender distribution')
plt.show()

# %% [markdown]
# ## COUNTPLOT

# %%
sns.set_theme(style="darkgrid")
sns.catplot(data = df, x = 'survived', kind ='count',palette = 'husl',)
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.catplot(data = df, x = 'gender', kind ='count')
plt.show()

# %% [markdown]
# ## How many Male and Female survived?

# %%
sns.set_theme(style="darkgrid")
sns.catplot(data= df, x = 'survived',
hue ='gender',kind ='count', order = ['yes','no'])  #order
plt.show()

# %%
sns.catplot(data = df, x = 'class', hue = 'survived',kind = 'count')
plt.show()

# %%
df2['DateTime']= pd.to_datetime(df2['DateTime'], errors='coerce')
df2
# Out:
#                  DateTime  Amount of Rainfall  Code
# 0     2020-08-01 02:00:00                   1   435
# 1     2020-08-01 05:00:00                   9   435
# 2     2020-08-01 08:00:00                   7   435
# 3     2020-08-01 11:00:00                   1   435
# 4     2020-08-01 14:00:00                   5   435
# ...                   ...                 ...   ...
# 13635 2020-08-31 11:00:00                   1   836
# 13636 2020-08-31 14:00:00                   9   836
# 13637 2020-08-31 17:00:00                   7   836
# 13638 2020-08-31 20:00:00                  12   836
# 13639 2020-08-31 23:00:00                   4   836
#
# [13640 rows x 3 columns]

# %%
df2['DateTime']=df2['DateTime'].dt.day
df2
# Out:
#        DateTime  Amount of Rainfall  Code
# 0             1                   1   435
# 1             1                   9   435
# 2             1                   7   435
# 3             1                   1   435
# 4             1                   5   435
# ...         ...                 ...   ...
# 13635        31                   1   836
# 13636        31                   9   836
# 13637        31                   7   836
# 13638        31                  12   836
# 13639        31                   4   836
#
# [13640 rows x 3 columns]

# %% [markdown]
# ## LINE PLOT

# %%
df2['Amount of Rainfall'].groupby(df2['DateTime']).mean().plot.line(figsize=(10,5))
plt.show()

# %% [markdown]
# ## JOINTPLOT

# %%
sns.jointplot(x='total_bill',y ='tip',data = df3)  #kde ,hue = 'sex'
plt.show()

# %% [markdown]
# ## SCATTER PLOT

# %%
sns.set_theme(style="darkgrid")
sns.relplot(x='total_bill',y ='tip',data = df3,kind ='scatter') #h
plt.show()

# %% [markdown]
# ## REGPLOT VS LMPLOT

# %%
fig,ax = plt.subplots(figsize = [10,5])
ax = sns.set_theme(style="darkgrid")
sns.regplot(x='total_bill',y ='tip',
data = df3) #ci = none  sca

plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.lmplot(x='total_bill',y ='tip',
                        hue = 'smoker', 
                        data = df3)
plt.show()

# %% [markdown]
# ## HISTPLOT

# %%
sns.set_theme(style="darkgrid")
fig,ax = plt.subplots(figsize = (10,10))
sns.histplot(data =df4final ,x="flipper_length_mm",
                            kde = True,
                            bins = 5,ax = ax)
plt.show()

# %% [markdown]
# ## DISTPLOT

# %%
sns.displot(df.age)   #kde rug and hist
plt.xlim=(1,80)
plt.show()

# %% [markdown]
# ## SWARMPLOT

# %%
fig,ax = plt.subplots(figsize = (10,10))
sns.swarmplot(x="species", 
 y="flipper_length_mm", #hue = 'sex' ,s
 data=df4final, ax = ax)
plt.show()

# %% [markdown]
# ## STRIPPLOT

# %%
 sns.stripplot(x="species", 
 y="flipper_length_mm", #hue = 'sex',
 data=df4final)  
plt.show()

# %% [markdown]
# ## BARPLOT

# %%
sns.barplot(x='sex', y= 'total_bill',data = df3, estimator = np.median) # std ,  meadian
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='species', y= 'body_mass_g',data = df4final)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>
